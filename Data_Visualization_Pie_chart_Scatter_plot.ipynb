# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranq-lgtm/Data-Visualization/blob/main/Data_%20Visualization_Pie_chart_Scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn

# %%
import matplotlib.pyplot as plt

# %%
data=[44,45,40,41,39]

# %%
keys=['class 1','class 2','class 3','class 4','class 5']

# %%
palette_color=seaborn.color_palette('bright')

# %%
plt.pie(data,labels=keys,colors=palette_color,autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ad49bf85390>,
# ...
#  [Text(0.8680545570066951, 0.675633988236168, 'class 1'),
#   Text(-0.456956527076959, 1.0005951890558762, 'class 2'),
#   Text(-1.089949385801992, -0.1483588096132503, 'class 3'),
#   Text(-0.23785930861680463, -1.0739753019992293, 'class 4'),
#   Text(0.9163353963858019, -0.6085469918835157, 'class 5')],
#  [Text(0.47348430382183365, 0.3685276299470007, '21%'),
#   Text(-0.24924901476925032, 0.5457791940304778, '22%'),
#   Text(-0.5945178468010864, -0.08092298706177288, '19%'),
#   Text(-0.1297414410637116, -0.5858047101813977, '20%'),
#   Text(0.4998193071195282, -0.331934722845554, '19%')])

# %%
plt.show()

# %%
explode=[0,0.1,0,0,0]

# %%
palette_color=seaborn.color_palette('dark')

# %%
plt.pie(data,labels=keys,colors=palette_color,explode=explode,autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ad49b75a320>,
# ...
#  [Text(0.8680545570066951, 0.675633988236168, 'class 1'),
#   Text(-0.49849802953850075, 1.0915583880609558, 'class 2'),
#   Text(-1.089949385801992, -0.1483588096132503, 'class 3'),
#   Text(-0.23785930861680463, -1.0739753019992293, 'class 4'),
#   Text(0.9163353963858019, -0.6085469918835157, 'class 5')],
#  [Text(0.47348430382183365, 0.3685276299470007, '21%'),
#   Text(-0.2907905172307921, 0.6367423930355575, '22%'),
#   Text(-0.5945178468010864, -0.08092298706177288, '19%'),
#   Text(-0.1297414410637116, -0.5858047101813977, '20%'),
#   Text(0.4998193071195282, -0.331934722845554, '19%')])

# %%
plt.show()

# %%
import seaborn

# %%
seaborn.set(style='whitegrid')

# %%
fmri=seaborn.load_dataset('fmri')

# %%
seaborn.scatterplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
iris=sns.load_dataset('iris')

# %%
fig=iris[iris.species=='setosa'].plot(kind='scatter',x='sepal_length',y='sepal_width',color='orange',label='setosa')

# %%
fig=iris[iris.species=='versicolor'].plot(kind='scatter',x='petal_length',y='petal_width',color='blue',label='versicolor')

# %%
fig=iris[iris.species=='virginica'].plot(kind='scatter',x='petal_length',y='petal_width',color='green',label='virginica')
