# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranq-lgtm/Data-Visualization/blob/main/Data_Visualisation_through_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install panda

# %%
import pandas as pd

# %%
data=pd.read_csv("/practice.csv")

# %%
data.head(7)
# Out:
#    ID Product Name  Sales  Region of max Sale category
# 0   1     Mobile 1  49.87               Ponda   Iphone
# 1   2     Mobile 2  33.67              Panjim  Android
# 2   3     Mobile 3  29.56              Panjim   Iphone
# 3   4     Mobile 4  25.82               Ponda  Android
# 4   5     Mobile 5  35.99              Margao   Iphone
# 5   6     Mobile 6  45.60              Margao  Android
# 6   7     Mobile 7  33.80              Margao   Iphone

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x="Product Name",y="Sales",data=data)
# Out:
# <Axes: xlabel='Product Name', ylabel='Sales'>

# %%
sns.barplot(x=" Region of max Sale",y="Sales",data=data)
# Out:
# <Axes: xlabel=' Region of max Sale', ylabel='Sales'>

# %%
sns.barplot(x=" Region of max Sale",y="Sales",hue="category",data=data)
# Out:
# <Axes: xlabel=' Region of max Sale', ylabel='Sales'>
