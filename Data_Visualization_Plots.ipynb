# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranq-lgtm/Data-Visualization/blob/main/Data_Visualization_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=sns.load_dataset("tips")

# %%
sns.barplot(x="day",y="total_bill",data=df)
plt.show()

# %%
sns.lineplot(x="day",y="total_bill",data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn
data=[44,45,40,41,39]
keys=['class 1','class 2','class 3','class 4','class 5']
palette_color=seaborn.color_palette('cool')
plt.pie(data,labels=keys,colors=palette_color,autopct='%.2f%%')
plt.show()

# %%
sns.histplot(df["total_bill"],kde=True)
plt.show()

# %%
sns.scatterplot(x="total_bill",y="tip",data=df)
plt.show()

# %%
sns.countplot(x="day",data=df)
plt.show()

# %%
sns.boxplot(x="day",y="total_bill",data=df)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.swarmplot(x="day",y="total_bill",data=df)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(low=1,high=100,size=(10,10))
print("the data plotted:\n")
print(data)
hm=sns.heatmap(data=data)
plt.show()
# Out:
# the data plotted:
#
# [[70 39 89 58 21  8 22 68 43 68]
#  [44 29 94 28  2 36 22 63 59  7]
#  [26  4 61 81 69 61 56  3 75 36]
#  [58 73 94 99 43 73 91  1  4 84]
#  [38 26 88 89 45  5 13 96 45 79]
#  [23 20 73 13 62 33 34  2 84 55]
#  [46 92 82 91 46 12 13 61 49 63]
#  [ 2 29  3 65 11 78 28 57 23 55]
#  [75 31 34 80 68 81 91 11  5 12]
#  [ 8 41 19 55 26 40 94 25 14 47]]
