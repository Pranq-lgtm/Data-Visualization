# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranq-lgtm/Data-Visualization/blob/main/Data_Visualisation_by_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('titanic')

# %%
sns.barplot(x='class',y='fare',data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
plt.show()

# %%
sns.barplot(x='class',y='fare',hue='sex',data=df)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
plt.show()

# %%
sns.barplot(x='fare',y='class',hue='sex',data=df)
# Out:
# <Axes: xlabel='fare', ylabel='class'>

# %%
plt.show()

# %%
sns.barplot(x='class',y='fare',data=df,order=['Third','Second','First'])
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
plt.show()

# %%
sns.barplot(x='class',y='fare',data=df,color="salmon")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
plt.show()

# %%
sns.barplot(x='class',y='fare',hue='sex',data=df,palette='pastel')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
plt.show()
